# %% [markdown]
# # Importer

# %%
import pandas as pd

# %%
chemin_fichier = "/Users/rezisabashvili/Desktop/anonymedata.csv"

df = pd.read_csv(chemin_fichier, low_memory=False)

df.head()
# Out:
#    idSite  idVisit                                            visitIp  \
# 0       1     8682  b31c78accedce63af24b9de40b6748ccfb4013d5cc7f57...
# 1       1     8680  a0929d66c9212e29730900910669794b974aeb0d6ab233...
# 2       1     8679  a0929d66c9212e29730900910669794b974aeb0d6ab233...
# 3       1     8681  a0929d66c9212e29730900910669794b974aeb0d6ab233...
# 4       1     8678  742a2df07f73ea60606e3bec8ef8b84a11877297487397...
#
#           visitorId       fingerprint type (actionDetails 0)  \
# 0  13ce8ab1cca64a5f  9e2e4438ec9d8920                 action
# 1  1f24d9d5f6ae4408  38ef5dbd6b801ccd                 action
# 2  3493fc460c9d7178  38ef5dbd6b801ccd                 action
# 3  6d87fcccf4de519e  dfe132cae95e2e75                 action
# 4  ef260fdb630a685b  ba3e54a775ebcd0c                 action
#
#                   url (actionDetails 0)  \
# 0        https://educapacites.fr/447-2/
# 1              https://educapacites.fr/
# 2  https://educapacites.fr/orientation/
# ...
